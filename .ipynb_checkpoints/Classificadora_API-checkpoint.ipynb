# %%
import requests
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Baixar recursos adicionais do NLTK
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Carregar os dados
data = pd.read_excel('Expanded_Dataset_Tweets.xlsx')

# Pré-processamento do texto
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('portuguese'))
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    processed_text = ' '.join(tokens)
    return processed_text

data['processed_tweets'] = data['tweets'].apply(preprocess_text)

# Dividir os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(data['processed_tweets'], data['classificador'], test_size=0.55, random_state=42)

# Criar o pipeline de classificação
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LinearSVC())
])

# Definir os hiperparâmetros para o GridSearch
param_grid = {
    'tfidf__max_df': [0.8, 0.9, 1.0],
    'tfidf__ngram_range': [(1,1), (1,2)],
    'clf__C': [0.1, 1, 10]
}

# Realizar o GridSearch com validação cruzada
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Imprimir os melhores hiperparâmetros
print(f"Melhores hiperparâmetros: {grid_search.best_params_}")

# Avaliar o modelo com os melhores hiperparâmetros
best_pipeline = grid_search.best_estimator_
predictions = best_pipeline.predict(X_test)
print(classification_report(y_test, predictions))


# URL da sua API
login_url = 'http://localhost:3000/auth/login'
# Credenciais do usuário
credentials = {
    'usuario': 'admin',
    'senha': 'admin'
}

# Fazendo uma solicitação POST para obter o token JWT
login_response = requests.post(login_url, json=credentials)
token = login_response.json()['token']
# Incluindo o token JWT no cabeçalho Authorization
headers = {
    'Authorization': "Bearer "+token
}

# Função para classificar tweets e atualizar no banco de dados
def classify_and_update_tweets(api_url):
    # Obter tweets da API
    response = requests.get(f"{api_url}/tweets", headers=headers)
    
    if response.status_code == 200:
        try:
            tweets = response.json()
        except ValueError:
            print("Erro ao decodificar JSON. Resposta não está no formato JSON.")
            return
        
        for tweet in tweets:
            tweet_text = tweet['texto']  # Ajuste este campo conforme a estrutura do seu JSON
            processed_text = preprocess_text(tweet_text)
            is_suicida = best_pipeline.predict([processed_text])[0] == 'Post  com Potencial Suicida'
            
            # Atualizar o campo isSuicida no tweet
            tweet_id = tweet['_id']  # Ajuste este campo conforme a estrutura do seu JSON
            update_url = f"{api_url}/tweets/{tweet_id}"
            update_data = {'isSuicida': is_suicida}
            update_response = requests.put(update_url, json=update_data, headers=headers)
            
            if update_response.status_code == 200:
                print(f"Tweet {tweet_id} atualizado com sucesso.")
            else:
                print(f"Erro ao atualizar o tweet {tweet_id}. Código de status:", update_response.status_code)
    else:
        print("Erro ao acessar a API. Código de status:", response.status_code)

# Definir URL da API
api_url = "http://localhost:3000"

# Classificar e atualizar tweets
classify_and_update_tweets(api_url)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Melhores hiperparâmetros: {'clf__C': 1, 'tfidf__max_df': 0.8, 'tfidf__ngram_range': (1, 1)}
#                              precision    recall  f1-score   support
#
# Post  com Potencial Suicida       0.94      0.92      0.93       264
#            Post Não Suicida       0.92      0.94      0.93       270
#
#                    accuracy                           0.93       534
#                   macro avg       0.93      0.93      0.93       534
#                weighted avg       0.93      0.93      0.93       534
#
# Tweet 663d79faa978d3f9816d889f atualizado com sucesso.
# Tweet 6640df8b3cfbb49b44d413a9 atualizado com sucesso.
# Tweet 66417f5b3cfbb49b44d41413 atualizado com sucesso.
# Tweet 66417f5b3cfbb49b44d41414 atualizado com sucesso.
# Tweet 66417f613cfbb49b44d41418 atualizado com sucesso.
# Tweet 66417f613cfbb49b44d41417 atualizado com sucesso.
# Tweet 664180103cfbb49b44d4141b atualizado com sucesso.
# Tweet 664180173cfbb49b44d4141d atualizado com sucesso.
# Tweet 664182133cfbb49b44d41433 atualizado com sucesso.
# Tweet 664182193cfbb49b44d41435 atualizado com sucesso.
# Tweet 664183093cfbb49b44d41437 atualizado com sucesso.
# Tweet 6641830f3cfbb49b44d4143d atualizado com sucesso.
# Tweet 664184623cfbb49b44d41443 atualizado com sucesso.
# Tweet 664184673cfbb49b44d41448 atualizado com sucesso.
# Tweet 664184da3cfbb49b44d4144d atualizado com sucesso.
# Tweet 664185213cfbb49b44d41451 atualizado com sucesso.
# Tweet 664185643cfbb49b44d41455 atualizado com sucesso.
# Tweet 664185b03cfbb49b44d41459 atualizado com sucesso.
# Tweet 664185b53cfbb49b44d4145d atualizado com sucesso.
# Tweet 6641861a3cfbb49b44d41461 atualizado com sucesso.
# Tweet 6641882d3cfbb49b44d41465 atualizado com sucesso.
# Tweet 664188333cfbb49b44d41467 atualizado com sucesso.
# Tweet 664fd50a3b61b1036b5de0e7 atualizado com sucesso.
# Tweet 664fd5243b61b1036b5de0e9 atualizado com sucesso.
# Tweet 664fd5b13b61b1036b5de0eb atualizado com sucesso.
# Tweet 664fd64f78b8d2784ac4a750 atualizado com sucesso.
# Tweet 664fd89f599762746f18b9fc atualizado com sucesso.
# Tweet 664fe05fc873721ee62f8ffb atualizado com sucesso.
# Tweet 664fe05fc873721ee62f9002 atualizado com sucesso.
# Tweet 664fe060c873721ee62f900a atualizado com sucesso.
# Tweet 664fe060c873721ee62f9013 atualizado com sucesso.
# Tweet 664fe061c873721ee62f901d atualizado com sucesso.
# Tweet 664fe062c873721ee62f9028 atualizado com sucesso.
# Tweet 664fe062c873721ee62f9035 atualizado com sucesso.
# Tweet 664fe063c873721ee62f9042 atualizado com sucesso.
# Tweet 6658f612e0170bf5ead28db4 atualizado com sucesso.
# Tweet 6658f618e0170bf5ead28db9 atualizado com sucesso.
# Tweet 6658f61ee0170bf5ead28dbf atualizado com sucesso.
# Tweet 665bbb063310fa58ab02b7d5 atualizado com sucesso.
# Tweet 665bbb063310fa58ab02b7db atualizado com sucesso.
# Tweet 665bbb073310fa58ab02b7e2 atualizado com sucesso.
# Tweet 665bbb083310fa58ab02b7ea atualizado com sucesso.
# Tweet 665bbb083310fa58ab02b7f3 atualizado com sucesso.
# Tweet 665bbb093310fa58ab02b7fd atualizado com sucesso.
# Tweet 665bbb093310fa58ab02b808 atualizado com sucesso.
# Tweet 665bbb0a3310fa58ab02b814 atualizado com sucesso.
# Tweet 665bbb0b3310fa58ab02b821 atualizado com sucesso.
# Tweet 665bbb0b3310fa58ab02b82f atualizado com sucesso.
# Tweet 665bbb0c3310fa58ab02b83e atualizado com sucesso.
# Tweet 665bbb0c3310fa58ab02b84e atualizado com sucesso.
# Tweet 665bbb0d3310fa58ab02b85f atualizado com sucesso.
# Tweet 665bbb133310fa58ab02b872 atualizado com sucesso.
# Tweet 665bbb153310fa58ab02b88b atualizado com sucesso.
# Tweet 665bbb163310fa58ab02b89c atualizado com sucesso.
# Tweet 665bbb173310fa58ab02b8ae atualizado com sucesso.
# Tweet 665bbb173310fa58ab02b8c1 atualizado com sucesso.
# Tweet 666797db06e5d1ee20a11150 atualizado com sucesso.
# Tweet 666797db06e5d1ee20a11165 atualizado com sucesso.
# Tweet 666797dc06e5d1ee20a1117b atualizado com sucesso.
# Tweet 666797e606e5d1ee20a1119d atualizado com sucesso.
# Tweet 666797e706e5d1ee20a111a2 atualizado com sucesso.
# Tweet 666797e706e5d1ee20a111a8 atualizado com sucesso.
# Tweet 666797e806e5d1ee20a111af atualizado com sucesso.
# Tweet 666797e806e5d1ee20a111b7 atualizado com sucesso.
# Tweet 666797e906e5d1ee20a111c0 atualizado com sucesso.
# Tweet 666797ea06e5d1ee20a111ca atualizado com sucesso.
# Tweet 666797eb06e5d1ee20a111d5 atualizado com sucesso.
# Tweet 666797eb06e5d1ee20a111e1 atualizado com sucesso.
# Tweet 666797ec06e5d1ee20a111ee atualizado com sucesso.
# Tweet 666797ec06e5d1ee20a111fc atualizado com sucesso.
# Tweet 666797ed06e5d1ee20a1120b atualizado com sucesso.
# Tweet 666797ed06e5d1ee20a1121b atualizado com sucesso.
# Tweet 666797ee06e5d1ee20a1122c atualizado com sucesso.
# Tweet 666797ee06e5d1ee20a1123e atualizado com sucesso.
# Tweet 6673a231fc131f48b577a17e atualizado com sucesso.
# Tweet 6674b6b0fc131f48b577a28b atualizado com sucesso.
# Tweet 6674b6b1fc131f48b577a290 atualizado com sucesso.
# Tweet 6674b6b1fc131f48b577a295 atualizado com sucesso.
# Tweet 6674b6b2fc131f48b577a29a atualizado com sucesso.
# Tweet 6674b6b3fc131f48b577a29f atualizado com sucesso.
# Tweet 6674b6b3fc131f48b577a2a4 atualizado com sucesso.
# Tweet 6674b6b4fc131f48b577a2a9 atualizado com sucesso.
# Tweet 6674b6b5fc131f48b577a2ae atualizado com sucesso.
# Tweet 6674b6b5fc131f48b577a2b3 atualizado com sucesso.
# Tweet 6674b6b6fc131f48b577a2b8 atualizado com sucesso.
# Tweet 6674b6b6fc131f48b577a2bd atualizado com sucesso.
# Tweet 6674b6b7fc131f48b577a2c2 atualizado com sucesso.
# Tweet 6674b6b8fc131f48b577a2c7 atualizado com sucesso.
# Tweet 6674b6b8fc131f48b577a2cc atualizado com sucesso.
# Tweet 6674b6b9fc131f48b577a2d1 atualizado com sucesso.
# Tweet 6674b6b9fc131f48b577a2d6 atualizado com sucesso.
# Tweet 6674b6bafc131f48b577a2db atualizado com sucesso.
# Tweet 6674b6bbfc131f48b577a2e0 atualizado com sucesso.
# Tweet 6674b6bbfc131f48b577a2e5 atualizado com sucesso.
# Tweet 6674b6bcfc131f48b577a2ea atualizado com sucesso.
# Tweet 6674b6bcfc131f48b577a2ef atualizado com sucesso.
# Tweet 6674b6bdfc131f48b577a2f4 atualizado com sucesso.
# Tweet 6674b6befc131f48b577a2f9 atualizado com sucesso.
# Tweet 6674b6befc131f48b577a2fe atualizado com sucesso.
# Tweet 6674b6bffc131f48b577a303 atualizado com sucesso.
# Tweet 6674b6c0fc131f48b577a308 atualizado com sucesso.
# Tweet 6674b6c0fc131f48b577a30d atualizado com sucesso.
# Tweet 6674b6c1fc131f48b577a312 atualizado com sucesso.
# Tweet 6674b6c1fc131f48b577a317 atualizado com sucesso.
# Tweet 6674b6c2fc131f48b577a31c atualizado com sucesso.
# Tweet 6674b6c2fc131f48b577a321 atualizado com sucesso.
# Tweet 6674b6c3fc131f48b577a326 atualizado com sucesso.
# Tweet 6674b6c4fc131f48b577a32b atualizado com sucesso.
# Tweet 6674b6c4fc131f48b577a330 atualizado com sucesso.
# Tweet 6674b6c5fc131f48b577a335 atualizado com sucesso.
# Tweet 6674b6c6fc131f48b577a33a atualizado com sucesso.
# Tweet 6674b6c6fc131f48b577a33f atualizado com sucesso.
# Tweet 6674b6c7fc131f48b577a344 atualizado com sucesso.
# Tweet 6674b6c7fc131f48b577a349 atualizado com sucesso.
# Tweet 6674b6c8fc131f48b577a34e atualizado com sucesso.
# Tweet 6674b6c8fc131f48b577a353 atualizado com sucesso.
# Tweet 6674b6c9fc131f48b577a358 atualizado com sucesso.
# Tweet 6674b6c9fc131f48b577a35d atualizado com sucesso.
# Tweet 6674b6cafc131f48b577a362 atualizado com sucesso.
# Tweet 6674b6cbfc131f48b577a367 atualizado com sucesso.
# Tweet 6674b6cbfc131f48b577a36c atualizado com sucesso.
# Tweet 6674b6ccfc131f48b577a371 atualizado com sucesso.
# Tweet 6674b6ccfc131f48b577a376 atualizado com sucesso.
# Tweet 6674b6cdfc131f48b577a37b atualizado com sucesso.
# Tweet 6674b6cdfc131f48b577a380 atualizado com sucesso.
# Tweet 6674b6defc131f48b577a385 atualizado com sucesso.
# Tweet 6674b6effc131f48b577a38a atualizado com sucesso.
# Tweet 6674b6effc131f48b577a38f atualizado com sucesso.
# Tweet 6674b6f0fc131f48b577a394 atualizado com sucesso.
# Tweet 6674b6f1fc131f48b577a399 atualizado com sucesso.
# Tweet 6674b6f1fc131f48b577a39e atualizado com sucesso.
# Tweet 6674b6f2fc131f48b577a3a3 atualizado com sucesso.
# Tweet 6674b6f2fc131f48b577a3a8 atualizado com sucesso.
# Tweet 6674b6f3fc131f48b577a3ad atualizado com sucesso.
# Tweet 6674b6f4fc131f48b577a3b2 atualizado com sucesso.
# Tweet 6674b6f4fc131f48b577a3b7 atualizado com sucesso.
# Tweet 6674b6f5fc131f48b577a3bc atualizado com sucesso.
# Tweet 6674b6f5fc131f48b577a3c1 atualizado com sucesso.
# Tweet 6674b6f6fc131f48b577a3c6 atualizado com sucesso.
# Tweet 6674b6f6fc131f48b577a3cb atualizado com sucesso.
# Tweet 6674b6f7fc131f48b577a3d0 atualizado com sucesso.
# Tweet 6674b6f7fc131f48b577a3d5 atualizado com sucesso.
# Tweet 6674b6f8fc131f48b577a3da atualizado com sucesso.
# Tweet 6674b6f9fc131f48b577a3df atualizado com sucesso.
# Tweet 6674b6f9fc131f48b577a3e4 atualizado com sucesso.
# Tweet 6674b6fafc131f48b577a3e9 atualizado com sucesso.
# Tweet 6674b6fbfc131f48b577a3ee atualizado com sucesso.
# Tweet 6674b6fbfc131f48b577a3f3 atualizado com sucesso.
# Tweet 6674b6fcfc131f48b577a3f8 atualizado com sucesso.
# Tweet 6674b6fdfc131f48b577a3fd atualizado com sucesso.
# Tweet 6674b6fdfc131f48b577a402 atualizado com sucesso.
# Tweet 6674b6fefc131f48b577a407 atualizado com sucesso.
# Tweet 6674b6fefc131f48b577a40c atualizado com sucesso.
# Tweet 6674b6fffc131f48b577a411 atualizado com sucesso.
# Tweet 6674b6fffc131f48b577a416 atualizado com sucesso.
# Tweet 6674b700fc131f48b577a41b atualizado com sucesso.
# Tweet 6674b701fc131f48b577a420 atualizado com sucesso.
# Tweet 6674b701fc131f48b577a425 atualizado com sucesso.
# Tweet 6674b702fc131f48b577a42a atualizado com sucesso.
# Tweet 6674b702fc131f48b577a42f atualizado com sucesso.
# Tweet 6674b703fc131f48b577a434 atualizado com sucesso.
# Tweet 6674b704fc131f48b577a439 atualizado com sucesso.
# Tweet 6674b704fc131f48b577a43e atualizado com sucesso.
# Tweet 6674b705fc131f48b577a443 atualizado com sucesso.
# Tweet 6674b705fc131f48b577a448 atualizado com sucesso.
# Tweet 6674b706fc131f48b577a44d atualizado com sucesso.
# Tweet 6674b707fc131f48b577a452 atualizado com sucesso.
# Tweet 6674b707fc131f48b577a457 atualizado com sucesso.
# Tweet 6674b708fc131f48b577a45c atualizado com sucesso.
# Tweet 6674b708fc131f48b577a461 atualizado com sucesso.
# Tweet 6674b709fc131f48b577a466 atualizado com sucesso.
# Tweet 6674b709fc131f48b577a46b atualizado com sucesso.
# Tweet 6674b70afc131f48b577a470 atualizado com sucesso.
# Tweet 6674b70bfc131f48b577a475 atualizado com sucesso.
# Tweet 6674b70bfc131f48b577a47a atualizado com sucesso.
# Tweet 6674b70cfc131f48b577a47f atualizado com sucesso.
# Tweet 6674b71cfc131f48b577a484 atualizado com sucesso.
# Tweet 6674b71cfc131f48b577a489 atualizado com sucesso.
# Tweet 6674b71dfc131f48b577a48e atualizado com sucesso.
# Tweet 6674b71efc131f48b577a493 atualizado com sucesso.
# Tweet 6674b71efc131f48b577a498 atualizado com sucesso.
# Tweet 6674b71ffc131f48b577a49d atualizado com sucesso.
# Tweet 6674b720fc131f48b577a4a2 atualizado com sucesso.
# Tweet 6674b720fc131f48b577a4a7 atualizado com sucesso.
# Tweet 6674b721fc131f48b577a4ac atualizado com sucesso.
# Tweet 6674b721fc131f48b577a4b1 atualizado com sucesso.
# Tweet 6674b722fc131f48b577a4b6 atualizado com sucesso.
# Tweet 6674b722fc131f48b577a4bb atualizado com sucesso.
# Tweet 6674b723fc131f48b577a4c0 atualizado com sucesso.
# Tweet 6674b723fc131f48b577a4c5 atualizado com sucesso.
# Tweet 6674b724fc131f48b577a4ca atualizado com sucesso.
# Tweet 6674b725fc131f48b577a4cf atualizado com sucesso.
# Tweet 6674b725fc131f48b577a4d4 atualizado com sucesso.
# Tweet 6674b726fc131f48b577a4d9 atualizado com sucesso.
# Tweet 6674b726fc131f48b577a4de atualizado com sucesso.
# Tweet 6674b727fc131f48b577a4e3 atualizado com sucesso.
# Tweet 6674b728fc131f48b577a4e8 atualizado com sucesso.
# Tweet 6674b728fc131f48b577a4ed atualizado com sucesso.
# Tweet 6674b729fc131f48b577a4f2 atualizado com sucesso.
# Tweet 6674b729fc131f48b577a4f7 atualizado com sucesso.
# Tweet 6674b72afc131f48b577a4fc atualizado com sucesso.
# Tweet 6674b72bfc131f48b577a501 atualizado com sucesso.
# Tweet 6674b72bfc131f48b577a506 atualizado com sucesso.
# Tweet 6674b72cfc131f48b577a50b atualizado com sucesso.
# Tweet 6674b72dfc131f48b577a510 atualizado com sucesso.
# Tweet 6674b72dfc131f48b577a515 atualizado com sucesso.
# Tweet 6674b72efc131f48b577a51a atualizado com sucesso.
# Tweet 6674b72efc131f48b577a51f atualizado com sucesso.
# Tweet 6674b72ffc131f48b577a524 atualizado com sucesso.
# Tweet 6674b730fc131f48b577a529 atualizado com sucesso.
# Tweet 6674b730fc131f48b577a52e atualizado com sucesso.
# Tweet 6674b731fc131f48b577a533 atualizado com sucesso.
# Tweet 6674b731fc131f48b577a538 atualizado com sucesso.
# Tweet 6674b732fc131f48b577a53d atualizado com sucesso.
# Tweet 6674b733fc131f48b577a542 atualizado com sucesso.
# Tweet 6674b733fc131f48b577a547 atualizado com sucesso.
# Tweet 6674b734fc131f48b577a54c atualizado com sucesso.
# Tweet 6674b735fc131f48b577a551 atualizado com sucesso.
# Tweet 6674b735fc131f48b577a556 atualizado com sucesso.
# Tweet 6674b736fc131f48b577a55b atualizado com sucesso.
# Tweet 6674b736fc131f48b577a560 atualizado com sucesso.
# Tweet 6674b737fc131f48b577a565 atualizado com sucesso.
# Tweet 6674b738fc131f48b577a56a atualizado com sucesso.
# Tweet 6674b738fc131f48b577a56f atualizado com sucesso.
# Tweet 6674b739fc131f48b577a574 atualizado com sucesso.
# Tweet 6674b739fc131f48b577a579 atualizado com sucesso.
# Tweet 6674b74ffc131f48b577a57e atualizado com sucesso.
# Tweet 6674b74ffc131f48b577a583 atualizado com sucesso.
# Tweet 6674b750fc131f48b577a588 atualizado com sucesso.
# Tweet 6674b750fc131f48b577a58d atualizado com sucesso.
# Tweet 6674b751fc131f48b577a592 atualizado com sucesso.
# Tweet 6674b752fc131f48b577a597 atualizado com sucesso.
# Tweet 6674b752fc131f48b577a59c atualizado com sucesso.
# Tweet 6674b753fc131f48b577a5a1 atualizado com sucesso.
# Tweet 6674b753fc131f48b577a5a6 atualizado com sucesso.
# Tweet 6674b754fc131f48b577a5ab atualizado com sucesso.
# Tweet 6674b755fc131f48b577a5b0 atualizado com sucesso.
# Tweet 6674b755fc131f48b577a5b5 atualizado com sucesso.
# Tweet 6674b756fc131f48b577a5ba atualizado com sucesso.
# Tweet 6674b757fc131f48b577a5bf atualizado com sucesso.
# Tweet 6674b757fc131f48b577a5c4 atualizado com sucesso.
# Tweet 6674b758fc131f48b577a5c9 atualizado com sucesso.
# Tweet 6674b758fc131f48b577a5ce atualizado com sucesso.
# Tweet 6674b759fc131f48b577a5d3 atualizado com sucesso.
# Tweet 6674b75afc131f48b577a5d8 atualizado com sucesso.
# Tweet 6674b75afc131f48b577a5dd atualizado com sucesso.
# Tweet 6674b75bfc131f48b577a5e2 atualizado com sucesso.
# Tweet 6674b75cfc131f48b577a5e7 atualizado com sucesso.
# Tweet 6674b75cfc131f48b577a5ec atualizado com sucesso.
# Tweet 6674b75dfc131f48b577a5f1 atualizado com sucesso.
# Tweet 6674b75efc131f48b577a5f6 atualizado com sucesso.
# Tweet 6674b75efc131f48b577a5fb atualizado com sucesso.
# Tweet 6674b75ffc131f48b577a600 atualizado com sucesso.
# Tweet 6674b75ffc131f48b577a605 atualizado com sucesso.
# Tweet 6674b760fc131f48b577a60a atualizado com sucesso.
# Tweet 6674b761fc131f48b577a60f atualizado com sucesso.
# Tweet 6674b761fc131f48b577a614 atualizado com sucesso.
# Tweet 6674b762fc131f48b577a619 atualizado com sucesso.
# Tweet 6674b762fc131f48b577a61e atualizado com sucesso.
# Tweet 6674b763fc131f48b577a623 atualizado com sucesso.
# Tweet 6674b764fc131f48b577a628 atualizado com sucesso.
# Tweet 6674b764fc131f48b577a62d atualizado com sucesso.
# Tweet 6674b765fc131f48b577a632 atualizado com sucesso.
# Tweet 6674b765fc131f48b577a637 atualizado com sucesso.
# Tweet 6674b766fc131f48b577a63c atualizado com sucesso.
# Tweet 6674b767fc131f48b577a641 atualizado com sucesso.
# Tweet 6674b767fc131f48b577a646 atualizado com sucesso.
# Tweet 6674b768fc131f48b577a64b atualizado com sucesso.
# Tweet 6674b768fc131f48b577a650 atualizado com sucesso.
# Tweet 6674b769fc131f48b577a655 atualizado com sucesso.
# Tweet 6674b76afc131f48b577a65a atualizado com sucesso.
# Tweet 6674b76afc131f48b577a65f atualizado com sucesso.
# Tweet 6674b76bfc131f48b577a664 atualizado com sucesso.
# Tweet 6674b76cfc131f48b577a669 atualizado com sucesso.
# Tweet 6674b76cfc131f48b577a66e atualizado com sucesso.
# Tweet 6674b76dfc131f48b577a673 atualizado com sucesso.
# Tweet 6674b782fc131f48b577a678 atualizado com sucesso.
# Tweet 6674b783fc131f48b577a67d atualizado com sucesso.
# Tweet 6674b783fc131f48b577a682 atualizado com sucesso.
# Tweet 6674b784fc131f48b577a687 atualizado com sucesso.
# Tweet 6674b785fc131f48b577a68c atualizado com sucesso.
# Tweet 6674b785fc131f48b577a691 atualizado com sucesso.
# Tweet 6674b786fc131f48b577a696 atualizado com sucesso.
# Tweet 6674b787fc131f48b577a69b atualizado com sucesso.
# Tweet 6674b787fc131f48b577a6a0 atualizado com sucesso.
# Tweet 6674b788fc131f48b577a6a5 atualizado com sucesso.
# Tweet 6674b788fc131f48b577a6aa atualizado com sucesso.
# Tweet 6674b789fc131f48b577a6af atualizado com sucesso.
# Tweet 6674b78afc131f48b577a6b4 atualizado com sucesso.
# Tweet 6674b78afc131f48b577a6b9 atualizado com sucesso.
# Tweet 6674b78bfc131f48b577a6be atualizado com sucesso.
# Tweet 6674b78bfc131f48b577a6c3 atualizado com sucesso.
# Tweet 6674b78cfc131f48b577a6c8 atualizado com sucesso.
# Tweet 6674b78dfc131f48b577a6cd atualizado com sucesso.
# Tweet 6674b78dfc131f48b577a6d2 atualizado com sucesso.
# Tweet 6674b78efc131f48b577a6d7 atualizado com sucesso.
# Tweet 6674b78efc131f48b577a6dc atualizado com sucesso.
# Tweet 6674b78ffc131f48b577a6e1 atualizado com sucesso.
# Tweet 6674b790fc131f48b577a6e6 atualizado com sucesso.
# Tweet 6674b790fc131f48b577a6eb atualizado com sucesso.
# Tweet 6674b791fc131f48b577a6f0 atualizado com sucesso.
# Tweet 6674b791fc131f48b577a6f5 atualizado com sucesso.
# Tweet 6674b792fc131f48b577a6fa atualizado com sucesso.
# Tweet 6674b793fc131f48b577a6ff atualizado com sucesso.
# Tweet 6674b793fc131f48b577a704 atualizado com sucesso.
# Tweet 6674b794fc131f48b577a709 atualizado com sucesso.
# Tweet 6674b794fc131f48b577a70e atualizado com sucesso.
# Tweet 6674b795fc131f48b577a713 atualizado com sucesso.
# Tweet 6674b796fc131f48b577a718 atualizado com sucesso.
# Tweet 6674b796fc131f48b577a71d atualizado com sucesso.
# Tweet 6674b797fc131f48b577a722 atualizado com sucesso.
# Tweet 6674b797fc131f48b577a727 atualizado com sucesso.
# Tweet 6674b798fc131f48b577a72c atualizado com sucesso.
# Tweet 6674b799fc131f48b577a731 atualizado com sucesso.
# Tweet 6674b799fc131f48b577a736 atualizado com sucesso.
# Tweet 6674b79afc131f48b577a73b atualizado com sucesso.
# Tweet 6674b79afc131f48b577a740 atualizado com sucesso.
# Tweet 6674b79bfc131f48b577a745 atualizado com sucesso.
# Tweet 6674b79cfc131f48b577a74a atualizado com sucesso.
# Tweet 6674b79cfc131f48b577a74f atualizado com sucesso.
# Tweet 6674b79dfc131f48b577a754 atualizado com sucesso.
# Tweet 6674b79efc131f48b577a759 atualizado com sucesso.
# Tweet 6674b7aefc131f48b577a75e atualizado com sucesso.
# Tweet 6674b7affc131f48b577a763 atualizado com sucesso.
# Tweet 6674b7b0fc131f48b577a768 atualizado com sucesso.
# Tweet 6674b7b0fc131f48b577a76d atualizado com sucesso.
# Tweet 6674b7b1fc131f48b577a772 atualizado com sucesso.
# Tweet 6674b7b1fc131f48b577a777 atualizado com sucesso.
# Tweet 6674b7b2fc131f48b577a77c atualizado com sucesso.
# Tweet 6674b7b3fc131f48b577a781 atualizado com sucesso.
